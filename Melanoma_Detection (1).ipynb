# %% [markdown]
# **Problem statement**:
# Build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %%
#mount google drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
#import the required libraries
import pathlib
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import PIL

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping

from tensorflow.keras.preprocessing.image import load_img

# %%
# Defining the path for train and test images
data_dir_train = pathlib.Path("/content/gdrive/MyDrive/Repo/Train/")
data_dir_test = pathlib.Path("/content/gdrive/MyDrive/Repo/Test/")

# %%
# Count the number of image in Train and Test directory
# Using the glob to retrieve files/pathnames matching a specified pattern.

#Train Image count
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)

#Test Image count
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2243
# 118

# %%
#Visualize one instance of all the class present in the dataset.

#image_dataset_from_directory() will return a tf.data.Dataset that yields batches of images from the subdirectories.
#label_mode is categorial, the labels are a float32 tensor of shape (batch_size, num_classes), representing a one-hot encoding of the class index.
image_dataset = tf.keras.preprocessing.image_dataset_from_directory(data_dir_train,batch_size=32,image_size=(180,180),
                                                                    label_mode='categorical',seed=123)

#all the classes of Skin Cancer
class_names = image_dataset.class_names

#Dictionary to store the path of image as per the class
files_path_dict = {}

for c in class_names:
    files_path_dict[c] = list(map(lambda x:str(data_dir_train)+'/'+c+'/'+x,os.listdir(str(data_dir_train)+'/'+c)))
    
#Visualize image 
plt.figure(figsize=(15,15))
index = 0
for c in class_names:
    path_list = files_path_dict[c][:1]
    index += 1
    plt.subplot(3,3,index)
    plt.imshow(load_img(path_list[0],target_size=(180,180)))
    plt.title(c)
    plt.axis("off")
# Out:
# Found 2243 files belonging to 9 classes.

# %% [markdown]
# **Visualize distribution of classes in the training dataset.**

# %%
def class_distribution_count(directory):
    
    #count number of image in each classes    
    count= []
    for path in pathlib.Path(directory).iterdir():
        if path.is_dir():
            count.append(len([name for name in os.listdir(path)
                               if os.path.isfile(os.path.join(path, name))]))
    
    #name of the classes
    sub_directory = [name for name in os.listdir(directory)
                    if os.path.isdir(os.path.join(directory, name))]
    
    #return dataframe with image count and class.
    return pd.DataFrame(list(zip(sub_directory,count)),columns =['Class', 'No. of Image'])

df = class_distribution_count(data_dir_train)
df
# Out:
#                         Class  No. of Image
# 0                    melanoma           438
# 1  pigmented benign keratosis           462
# 2                       nevus           357
# 3        basal cell carcinoma           376
# 4           actinic keratosis           114
# 5     squamous cell carcinoma           181
# 6             vascular lesion           143
# 7        seborrheic keratosis            77
# 8              dermatofibroma            95

# %%
#Visualize the Number of image in each class.
import seaborn as sns
plt.figure(figsize=(10, 8))
sns.barplot(x="No. of Image", y="Class", data=df,
            label="Class")

# %% [markdown]
# **There is a class imbalance to solve this using a python package Augmentor (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.**

# %%
#install Augmentor
# !pip install Augmentor
# Out:
# Collecting Augmentor
#   Downloading Augmentor-0.2.9-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (4.64.0)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (1.21.6)
# Requirement already satisfied: future>=0.16.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (0.16.0)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (7.1.2)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.9

# %%
path_to_training_dataset="/content/gdrive/MyDrive/Repo/Train/"
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500)  #Adding 500 samples per class to make sure that none of the classes are sparse
# Out:
# Initialised with 114 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Repo/Train/actinic keratosis/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7F1B1F5F1350>: 100%|██████████| 500/500 [00:22<00:00, 21.82 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Repo/Train/basal cell carcinoma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7F1B1F54ECD0>: 100%|██████████| 500/500 [00:22<00:00, 22.03 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Repo/Train/dermatofibroma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F1B248B0510>: 100%|██████████| 500/500 [00:23<00:00, 21.13 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Repo/Train/melanoma/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F1B1F554210>: 100%|██████████| 500/500 [01:53<00:00,  4.41 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Repo/Train/nevus/output.
# Processing <PIL.Image.Image image mode=RGB size=1504x1129 at 0x7F1B1F58C250>: 100%|██████████| 500/500 [01:39<00:00,  5.04 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Repo/Train/pigmented benign keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F1B9F27B4D0>: 100%|██████████| 500/500 [00:23<00:00, 21.57 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Repo/Train/seborrheic keratosis/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x7F1B9F350C10>: 100%|██████████| 500/500 [00:50<00:00,  9.96 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Repo/Train/squamous cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F1B9F170650>: 100%|██████████| 500/500 [00:22<00:00, 22.24 Samples/s]
# Initialised with 143 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Repo/Train/vascular lesion/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F1B9F25CE10>: 100%|██████████| 500/500 [00:24<00:00, 20.75 Samples/s]

# %%
#Count total number of image generated by Augmentor.
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 4500

# %% [markdown]
# *Model Building*

# %%
# train dataset 
train_ds = tf.keras.preprocessing.image_dataset_from_directory(data_dir_train, batch_size=32,
                                                               image_size=(180,180), label_mode='categorical',
                                                               seed=123,subset="training",
                                                               validation_split=0.2)

#label_mode is categorial, the labels are a float32 tensor of shape (batch_size, num_classes),
#representing a one-hot encoding of the class index.
# Out:
# Found 6743 files belonging to 9 classes.
# Using 5395 files for training.

# %%
# validation dataset 
val_ds =tf.keras.preprocessing.image_dataset_from_directory(data_dir_train,batch_size=32,
                                                            image_size=(180,180), label_mode='categorical',
                                                            seed=123,subset="validation",
                                                            validation_split=0.2)
# Out:
# Found 6743 files belonging to 9 classes.
# Using 1348 files for validation.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
#Sequential allows you to create models layer-by-layer  
model = Sequential()

model.add(layers.experimental.preprocessing.Rescaling(1./255,input_shape=(180,180,3)))   #Rescaling Layer

#First Convulation layer
model.add(layers.Conv2D(32,kernel_size=(3,3),activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))

#Second Convulation Layer
model.add(layers.Conv2D(64,kernel_size=(3,3),activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))

#Third Convulation Layer
model.add(layers.Conv2D(128,kernel_size=(3,3),activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))

#Dropout layer with 50% Fraction of the input units to drop.
model.add(layers.Dropout(0.5))

#Flatten Layer
##Keras.layers.flatten function flattens the multi-dimensional input tensors into a single dimension.
model.add(layers.Flatten())

#Dense Layer
model.add(layers.Dense(128,activation='relu'))

#Dropout layer with 25% Fraction of the input units to drop.
model.add(layers.Dropout(0.25))

#Dense Layer with softmax activation function.
#Softmax is an activation function that scales numbers/logits into probabilities.
model.add(layers.Dense(len(class_names),activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 178, 178, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 89, 89, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 87, 87, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 43, 43, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 41, 41, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 20, 20, 128)      0
#  2D)
#
#  dropout (Dropout)           (None, 20, 20, 128)       0
#
#  flatten (Flatten)           (None, 51200)             0
#
#  dense (Dense)               (None, 128)               6553728
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 6,648,137
# Trainable params: 6,648,137
# Non-trainable params: 0
# _________________________________________________________________

# %%
# vizualizing the model 
from tensorflow.keras.utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
#Compile the Model

#Adam optimization: is a stochastic gradient descent method that is based on adaptive estimation of first-order and second-order moments.
#categorical_crossentropy: Used as a loss function for multi-class classification model where there are two or more output labels.

model.compile(optimizer="Adam",loss="categorical_crossentropy",metrics=["accuracy"])

#ModelCheckpoint callback is used in conjunction with training using model.fit() to save a model or weights (in a checkpoint file) at some interval,
#so the model or weights can be loaded later to continue the training from the state saved.
checkpoint = ModelCheckpoint("model.h5",monitor="val_accuracy",save_best_only=True,mode="auto",verbose=1)

#Stop training when a monitored metric has stopped improving.
earlystop = EarlyStopping(monitor="val_accuracy",patience=5,mode="auto",verbose=1)

# %%
# Train the model
epochs = 20
history = model.fit(train_ds, validation_data=val_ds, epochs=epochs,callbacks=[checkpoint,earlystop])
# Out:
# Epoch 1/20
# 169/169 [==============================] - ETA: 0s - loss: 1.9756 - accuracy: 0.2504
# Epoch 1: val_accuracy improved from -inf to 0.36128, saving model to model.h5
# 169/169 [==============================] - 61s 122ms/step - loss: 1.9756 - accuracy: 0.2504 - val_loss: 1.6466 - val_accuracy: 0.3613
# Epoch 2/20
# 169/169 [==============================] - ETA: 0s - loss: 1.5759 - accuracy: 0.3974
# Epoch 2: val_accuracy improved from 0.36128 to 0.44139, saving model to model.h5
# 169/169 [==============================] - 13s 79ms/step - loss: 1.5759 - accuracy: 0.3974 - val_loss: 1.5217 - val_accuracy: 0.4414
# Epoch 3/20
# 169/169 [==============================] - ETA: 0s - loss: 1.4579 - accuracy: 0.4482
# Epoch 3: val_accuracy improved from 0.44139 to 0.48665, saving model to model.h5
# 169/169 [==============================] - 13s 79ms/step - loss: 1.4579 - accuracy: 0.4482 - val_loss: 1.3685 - val_accuracy: 0.4866
# Epoch 4/20
# 169/169 [==============================] - ETA: 0s - loss: 1.3368 - accuracy: 0.5064
# Epoch 4: val_accuracy improved from 0.48665 to 0.51484, saving model to model.h5
# 169/169 [==============================] - 13s 78ms/step - loss: 1.3368 - accuracy: 0.5064 - val_loss: 1.2821 - val_accuracy: 0.5148
# Epoch 5/20
# 169/169 [==============================] - ETA: 0s - loss: 1.1957 - accuracy: 0.5503
# Epoch 5: val_accuracy improved from 0.51484 to 0.57196, saving model to model.h5
# 169/169 [==============================] - 13s 78ms/step - loss: 1.1957 - accuracy: 0.5503 - val_loss: 1.1828 - val_accuracy: 0.5720
# Epoch 6/20
# 169/169 [==============================] - ETA: 0s - loss: 1.1367 - accuracy: 0.5733
# Epoch 6: val_accuracy did not improve from 0.57196
# 169/169 [==============================] - 13s 78ms/step - loss: 1.1367 - accuracy: 0.5733 - val_loss: 1.1567 - val_accuracy: 0.5542
# Epoch 7/20
# 169/169 [==============================] - ETA: 0s - loss: 1.0665 - accuracy: 0.6024
# Epoch 7: val_accuracy improved from 0.57196 to 0.62611, saving model to model.h5
# 169/169 [==============================] - 13s 79ms/step - loss: 1.0665 - accuracy: 0.6024 - val_loss: 1.0298 - val_accuracy: 0.6261
# Epoch 8/20
# 169/169 [==============================] - ETA: 0s - loss: 0.9700 - accuracy: 0.6423
# Epoch 8: val_accuracy improved from 0.62611 to 0.65727, saving model to model.h5
# 169/169 [==============================] - 13s 79ms/step - loss: 0.9700 - accuracy: 0.6423 - val_loss: 0.9696 - val_accuracy: 0.6573
# Epoch 9/20
# 169/169 [==============================] - ETA: 0s - loss: 0.8994 - accuracy: 0.6675
# Epoch 9: val_accuracy improved from 0.65727 to 0.66766, saving model to model.h5
# 169/169 [==============================] - 13s 79ms/step - loss: 0.8994 - accuracy: 0.6675 - val_loss: 0.9167 - val_accuracy: 0.6677
# Epoch 10/20
# 169/169 [==============================] - ETA: 0s - loss: 0.7867 - accuracy: 0.7138
# Epoch 10: val_accuracy improved from 0.66766 to 0.70475, saving model to model.h5
# 169/169 [==============================] - 13s 79ms/step - loss: 0.7867 - accuracy: 0.7138 - val_loss: 0.8409 - val_accuracy: 0.7047
# Epoch 11/20
# 169/169 [==============================] - ETA: 0s - loss: 0.7307 - accuracy: 0.7283
# Epoch 11: val_accuracy improved from 0.70475 to 0.72478, saving model to model.h5
# 169/169 [==============================] - 13s 79ms/step - loss: 0.7307 - accuracy: 0.7283 - val_loss: 0.7723 - val_accuracy: 0.7248
# Epoch 12/20
# 169/169 [==============================] - ETA: 0s - loss: 0.6681 - accuracy: 0.7500
# Epoch 12: val_accuracy improved from 0.72478 to 0.75371, saving model to model.h5
# 169/169 [==============================] - 13s 79ms/step - loss: 0.6681 - accuracy: 0.7500 - val_loss: 0.7641 - val_accuracy: 0.7537
# Epoch 13/20
# 169/169 [==============================] - ETA: 0s - loss: 0.6274 - accuracy: 0.7718
# Epoch 13: val_accuracy did not improve from 0.75371
# 169/169 [==============================] - 13s 78ms/step - loss: 0.6274 - accuracy: 0.7718 - val_loss: 0.7488 - val_accuracy: 0.7411
# Epoch 14/20
# 169/169 [==============================] - ETA: 0s - loss: 0.5636 - accuracy: 0.7963
# Epoch 14: val_accuracy improved from 0.75371 to 0.77745, saving model to model.h5
# 169/169 [==============================] - 13s 78ms/step - loss: 0.5636 - accuracy: 0.7963 - val_loss: 0.6624 - val_accuracy: 0.7774
# Epoch 15/20
# 169/169 [==============================] - ETA: 0s - loss: 0.5232 - accuracy: 0.8120
# Epoch 15: val_accuracy did not improve from 0.77745
# 169/169 [==============================] - 13s 77ms/step - loss: 0.5232 - accuracy: 0.8120 - val_loss: 0.6949 - val_accuracy: 0.7752
# Epoch 16/20
# 169/169 [==============================] - ETA: 0s - loss: 0.5305 - accuracy: 0.8044
# Epoch 16: val_accuracy did not improve from 0.77745
# 169/169 [==============================] - 13s 77ms/step - loss: 0.5305 - accuracy: 0.8044 - val_loss: 0.8949 - val_accuracy: 0.7151
# Epoch 17/20
# 169/169 [==============================] - ETA: 0s - loss: 0.4970 - accuracy: 0.8178
# Epoch 17: val_accuracy improved from 0.77745 to 0.78932, saving model to model.h5
# 169/169 [==============================] - 13s 79ms/step - loss: 0.4970 - accuracy: 0.8178 - val_loss: 0.6885 - val_accuracy: 0.7893
# Epoch 18/20
# 169/169 [==============================] - ETA: 0s - loss: 0.4253 - accuracy: 0.8487
# Epoch 18: val_accuracy did not improve from 0.78932
# 169/169 [==============================] - 13s 77ms/step - loss: 0.4253 - accuracy: 0.8487 - val_loss: 0.7396 - val_accuracy: 0.7745
# Epoch 19/20
# 169/169 [==============================] - ETA: 0s - loss: 0.3858 - accuracy: 0.8547
# Epoch 19: val_accuracy improved from 0.78932 to 0.80712, saving model to model.h5
# 169/169 [==============================] - 13s 78ms/step - loss: 0.3858 - accuracy: 0.8547 - val_loss: 0.6723 - val_accuracy: 0.8071
# Epoch 20/20
# 169/169 [==============================] - ETA: 0s - loss: 0.3960 - accuracy: 0.8547
# Epoch 20: val_accuracy did not improve from 0.80712
# 169/169 [==============================] - 13s 77ms/step - loss: 0.3960 - accuracy: 0.8547 - val_loss: 0.8055 - val_accuracy: 0.7507

# %%
# Plot the training curves

epochs_range = range(earlystop.stopped_epoch+1)

plt.figure(figsize=(15, 10))
plt.subplot(1, 2, 1)

#Plot Model Accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel(epochs_range)
plt.legend(['train', 'val'], loc='upper left')

#Plot Model Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel(epochs_range)
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
from glob import glob
Test_image_path = os.path.join(data_dir_test, class_names[1], '*')
Test_image = glob(Test_image_path)
Test_image = load_img(Test_image[1],target_size=(180,180,3))
plt.imshow(Test_image)
plt.grid(False)

img = np.expand_dims(Test_image,axis=0)
pred = model.predict(img)
pred = np.argmax(pred)
pred_class = class_names[pred]
print("Actual Class "+ class_names[1] +'\n'+ "Predictive Class "+pred_class )
# Out:
# Actual Class basal cell carcinoma
# Predictive Class basal cell carcinoma

# %%
from glob import glob
Test_image_path = os.path.join(data_dir_test, class_names[1], '*')
Test_image = glob(Test_image_path)
Test_image = load_img(Test_image[2],target_size=(180,180,3))
plt.imshow(Test_image)
plt.grid(False)

img = np.expand_dims(Test_image,axis=0)
pred = model.predict(img)
pred = np.argmax(pred)
pred_class = class_names[pred]
print("Actual Class "+ class_names[1] +'\n'+ "Predictive Class "+pred_class )
# Out:
# Actual Class basal cell carcinoma
# Predictive Class basal cell carcinoma

# %%
from glob import glob
Test_image_path = os.path.join(data_dir_test, class_names[1], '*')
Test_image = glob(Test_image_path)
Test_image = load_img(Test_image[5],target_size=(180,180,3))
plt.imshow(Test_image)
plt.grid(False)

img = np.expand_dims(Test_image,axis=0)
pred = model.predict(img)
pred = np.argmax(pred)
pred_class = class_names[pred]
print("Actual Class "+ class_names[1] +'\n'+ "Predictive Class "+pred_class )
# Out:
# Actual Class basal cell carcinoma
# Predictive Class basal cell carcinoma

# %%
from glob import glob
Test_image_path = os.path.join(data_dir_test, class_names[1], '*')
Test_image = glob(Test_image_path)
Test_image = load_img(Test_image[10],target_size=(180,180,3))
plt.imshow(Test_image)
plt.grid(False)

img = np.expand_dims(Test_image,axis=0)
pred = model.predict(img)
pred = np.argmax(pred)
pred_class = class_names[pred]
print("Actual Class "+ class_names[1] +'\n'+ "Predictive Class "+pred_class )
# Out:
# Actual Class basal cell carcinoma
# Predictive Class basal cell carcinoma

# %%
from glob import glob
Test_image_path = os.path.join(data_dir_test, class_names[1], '*')
Test_image = glob(Test_image_path)
Test_image = load_img(Test_image[9],target_size=(180,180,3))
plt.imshow(Test_image)
plt.grid(False)

img = np.expand_dims(Test_image,axis=0)
pred = model.predict(img)
pred = np.argmax(pred)
pred_class = class_names[pred]
print("Actual Class "+ class_names[1] +'\n'+ "Predictive Class "+pred_class )
# Out:
# Actual Class basal cell carcinoma
# Predictive Class basal cell carcinoma

# %% [markdown]
# **With achieving 80% validation accuracy we can conclude that this model is working fine.**
